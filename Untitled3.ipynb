# %%
#importing libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Reading the csv file
ol = pd.read_csv("Details.csv")
ol
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
#data cleaning.
ol.shape
# Out:
# (1500, 7)

# %%
ol.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
# 2  B-25955    2927     146         8    Furniture         Bookcases
# 3  B-26093    2847     712         8  Electronics          Printers
# 4  B-25602    2617    1151         4  Electronics            Phones
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card
# 4  Credit Card

# %%
ol.describe()
# Out:
#             Amount      Profit     Quantity
# count  1500.000000  1500.00000  1500.000000
# mean    291.847333    24.64200     3.743333
# std     461.924620   168.55881     2.184942
# min       4.000000 -1981.00000     1.000000
# 25%      47.750000   -12.00000     2.000000
# 50%     122.000000     8.00000     3.000000
# 75%     326.250000    38.00000     5.000000
# max    5729.000000  1864.00000    14.000000

# %%
ol.isnull().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# dtype: int64

# %%
ol.dtypes
# Out:
# Order ID        object
# Amount           int64
# Profit           int64
# Quantity         int64
# Category        object
# Sub-Category    object
# PaymentMode     object
# dtype: object

# %%
ol.dropna()
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
ol.nunique()
# Out:
# Order ID        500
# Amount          590
# Profit          406
# Quantity         14
# Category          3
# Sub-Category     17
# PaymentMode       5
# dtype: int64

# %%
ol.rename(columns = {'Order ID' : 'order_id', 'Sub-Category': 'sub_category', 'PaymentMode' : 'payment_mode'}, inplace = True)

# %%
ol.columns
# Out:
# Index(['order_id', 'Amount', 'Profit', 'Quantity', 'Category', 'sub_category',
#        'payment_mode'],
#       dtype='object')

# %%
ol.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
numeric_data = ol.select_dtypes(include=['number'])

# Compute the correlation matrix
correlation_matrix = numeric_data.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#             Amount    Profit  Quantity
# Amount    1.000000  0.309242  0.352486
# Profit    0.309242  1.000000  0.063096
# Quantity  0.352486  0.063096  1.000000

# %%
ol
# Out:
#      order_id  Amount  Profit  Quantity     Category      sub_category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#      payment_mode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
#defining the function 
def Details(data, col_1, col_4 ):
    '''
    The above function is used to create a line plot for Online Sales data
    
    Parameters:
    - data: DataFrame containing the data.
    - col_3: Name of the column for Quantity.
    - col_2: Name of the column for Profit.
    
    Returns:
    Results show a line plot between Quantity and Profit.

    '''
    
 #plotting data to show in the line graph   
    sns.lineplot(x='Quantity', y='Profit', data=ol, errorbar=('ci', False), hue='Category', marker='o')

    plt.grid()
    plt.xlabel('Quantity')
    plt.ylabel('Profit')
    plt.title('Quantity vs Profit')

    plt.show()
#calling the function
Details(ol, 'Quantity' , 'Profit')

# %%
#defining the function
def Details(data, col_5, col_1):
    '''
    The above function is used to create a bar graph for Online Sales data
    
    Parameters:
    - data: DataFrame containing the data.
    - col_5: Name of the column for sub_category.
    - col_1: Name of the column for Amount.
    
    Returns:
    Results show a bar graph between sub_category and Amount.
    '''
#plotting the data for showing the bar graph
    plt.figure(figsize = (20,8))
    sns.barplot(x='sub_category', y='Amount', data=ol, errorbar=None)

    plt.xlabel('sub_category', labelpad=14)
    plt.ylabel('Amount', labelpad=14)
    plt.title('Total Amount by Sub Category')

    plt.show()
#calling the function
Details(ol, 'sub_category', 'Amount')

# %%
#defining the function  
def Details(data, col_6, col_2):
    '''
    The above function is used to create a box plot for Online Sales data
    
    Returns:
    Results shows box plot between payment mode and Profit
    
    '''

    sns.boxplot(x = 'payment_mode', y = 'Profit', data = ol, showfliers = False)

#plotting data to create a box plot    
    plt.xlabel('Payment Mode', labelpad = 14)
    plt.ylabel('Profit', labelpad = 14)
    plt.title('Distribution of Profit by Payment Mode')

    plt.tight_layout()
    plt.show()
#calling the function    
Details(ol, 'payment_mode', 'Profit')
